# %%
#installed citipy and seaborn
#! pip install citipy
#! pip install seaborn

# %%
#import dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import random
import citipy
import seaborn as sns

# %%
# openweather api key
api_key = "e5760248211a864fbc4f4418cc6d872d"

# %%
#from citipy import citipy

#import cities from citipy
cities = pd.read_csv("https://raw.githubusercontent.com/wingchen/citipy/master/citipy/worldcities.csv")


#take a sample of 500 cities
random_cities = pd.DataFrame(cities.sample(n=550))
random_cities.reset_index(inplace = True)
random_cities
# Out:
#      index Country            City   Latitude   Longitude
# 0    45539      us        gallatin  36.388333  -86.446667
# 1    42605      us         visalia  36.330278 -119.291111
# 2     7354      co     santa maria   2.861389  -75.597778
# 3    34354      ro        stelnica  44.416667   27.883333
# 4       82      al          cerrik  41.031667   19.975833
# 5    35725      ru           domna  51.897122  113.157302
# 6    16312      id           kamal  -7.167778  112.719167
# 7    28434      ph         kapatan   5.900556  125.237500
# 8    12544      gb     fraserburgh  57.683333   -2.016667
# 9    19034      in      pithapuram  17.116667   82.266667
# 10   18262      in       khudaganj  28.150000   79.716667
# 11   19252      in         saidpur  28.616667   77.916667
# 12   41693      ua       semenivka  49.590311   33.180486
# 13   26958      ph            akle  15.048200  121.073300
# 14   26506      pa          pedasi   7.533333  -80.033333
# 15   10078      dk  neder vindinge  55.032107   11.883556
# 16   41418      ua        kulevcha  46.030338   29.936137
# 17   41385      ua           kosiv  48.310708   25.095752
# 18   43852      us       billerica  42.558333  -71.269444
# 19    1842      be        zonhoven  50.983333    5.350000
# 20   10953      es        ondarroa  43.325088   -2.423304
# 21   17816      in      hailakandi  24.683333   92.566667
# 22   23852      mx       hopelchen  19.766667  -89.850000
# 23    4537      ca        clermont  47.683333  -70.233333
# 24   40516      tr            biga  40.228056   27.242222
# 25    6298      cn        shangqiu  34.383333  115.616667
# 26   19395      in       shirhatti  15.233333   75.583333
# 27    7256      co          rondon   5.356415  -73.209178
# 28   15239      hn      vivistorio  14.900000  -88.733333
# 29   37223      ru      nikolskoye  55.193889  165.992500
# ..     ...     ...             ...        ...         ...
# 470  20934      it        san remo  43.816667    7.766667
# 471  42441      us   newport beach  33.618889 -117.928056
# 472  38414      ru        suponevo  53.204923   34.295966
# 473  26454      pa         la mesa   8.150000  -81.183333
# 474  36424      ru        koltsovo  56.774748   60.825227
# 475    196      am           aygek  40.188611   44.383333
# 476  37449      ru     oktyabrskiy  56.509909   57.204514
# 477  22490      lu        capellen  49.645000    5.990833
# 478  18628      in          minjur  13.266667   80.266667
# 479  28332      ph        indulang   8.050000  124.640000
# 480  27909      ph          clarin   9.961600  124.025200
# 481  39623      sk           cadca  49.433333   18.783333
# 482  13933      gr         methoni  36.816667   21.700000
# 483  39135      ru         yevsino  54.413600   83.322000
# 484  44789      us      middletown  41.445833  -74.423333
# 485  23793      mx          espita  21.016667  -88.316667
# 486  11550      fr      creutzwald  49.199657    6.689863
# 487  32085      ro      alba iulia  46.066667   23.583333
# 488  28812      ph       macabugos  13.236200  123.305300
# 489  22483      lu           biwer  49.702778    6.374722
# 490  20819      it           prato  43.883333   11.100000
# 491   4857      ca       peachland  49.766667 -119.750000
# 492  44955      us       dickinson  46.879167 -102.789167
# 493  46418      vn          hoi an  15.879444  108.335000
# 494  14340      gr        vasiliki  39.638889   21.704722
# 495  43769      us        ferndale  39.183056  -76.640556
# 496  44527      us        fort dix  40.029722  -74.618889
# 497  31849      pt         ventosa  39.126960   -9.084235
# 498  19927      ir         mahabad  36.749900   45.722900
# 499  24298      mx          petapa  16.816667  -95.150000
#
# [500 rows x 5 columns]

# %%
# openweathermap API
rowcount = 0
random_cities['Temperature'] = ""
random_cities['Humidity'] = ""
random_cities['Cloudiness'] = ""
random_cities['Wind Speed'] = ""


for index, row in random_cities.iterrows():
   
    
    targetCityNumber = row['index']
    targetCity = row['City']
    targetCountry = row['Country']
    targetURL = "http://api.openweathermap.org/data/2.5/weather?q={},{}&units=IMPERIAL&mode=json&APPID={}".format(targetCity, targetCountry, api_key)
    targetURL = targetURL.replace(" ","+")
    
    cityWeather = requests.get(targetURL).json()
    
    try:
        tempF = cityWeather["main"]["temp"]
        humidity = cityWeather["main"]["humidity"]
        cloudiness = cityWeather["clouds"]["all"]
        windspeed = cityWeather["wind"]["speed"]

        random_cities.set_value(index, "Temperature", tempF)
        random_cities.set_value(index, "Humidity", humidity)
        random_cities.set_value(index, "Cloudiness", cloudiness)
        random_cities.set_value(index, "Wind Speed", windspeed)
    except:
        continue

       
    
    rowcount+=1
    
    print("----------------------------")
    print("Retreiving City #: {}".format(rowcount))
    print("City Number: {}".format(targetCityNumber))
    print("City: {}".format(targetCity))
    print("Country: {}".format(targetCountry))
    print(targetURL)
    
randomcitiesDF = pd.DataFrame(random_cities)
randomcitiesDF
# Out:
# ----------------------------
# Retreiving City #: 1
# City Number: 45539
# City: gallatin
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=gallatin,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 2
# City Number: 42605
# City: visalia
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=visalia,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 3
# City Number: 7354
# City: santa maria
# Country: co
# http://api.openweathermap.org/data/2.5/weather?q=santa+maria,co&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 4
# City Number: 34354
# City: stelnica
# Country: ro
# http://api.openweathermap.org/data/2.5/weather?q=stelnica,ro&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 5
# City Number: 82
# City: cerrik
# Country: al
# http://api.openweathermap.org/data/2.5/weather?q=cerrik,al&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 6
# City Number: 35725
# City: domna
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=domna,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 7
# City Number: 16312
# City: kamal
# Country: id
# http://api.openweathermap.org/data/2.5/weather?q=kamal,id&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 8
# City Number: 28434
# City: kapatan
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=kapatan,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 9
# City Number: 12544
# City: fraserburgh
# Country: gb
# http://api.openweathermap.org/data/2.5/weather?q=fraserburgh,gb&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 10
# City Number: 19034
# City: pithapuram
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=pithapuram,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 11
# City Number: 18262
# City: khudaganj
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=khudaganj,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 12
# City Number: 19252
# City: saidpur
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=saidpur,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 13
# City Number: 41693
# City: semenivka
# Country: ua
# http://api.openweathermap.org/data/2.5/weather?q=semenivka,ua&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 14
# City Number: 26958
# City: akle
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=akle,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 15
# City Number: 26506
# City: pedasi
# Country: pa
# http://api.openweathermap.org/data/2.5/weather?q=pedasi,pa&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 16
# City Number: 10078
# City: neder vindinge
# Country: dk
# http://api.openweathermap.org/data/2.5/weather?q=neder+vindinge,dk&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 17
# City Number: 41418
# City: kulevcha
# Country: ua
# http://api.openweathermap.org/data/2.5/weather?q=kulevcha,ua&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 18
# City Number: 41385
# City: kosiv
# Country: ua
# http://api.openweathermap.org/data/2.5/weather?q=kosiv,ua&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 19
# City Number: 43852
# City: billerica
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=billerica,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 20
# City Number: 1842
# City: zonhoven
# Country: be
# http://api.openweathermap.org/data/2.5/weather?q=zonhoven,be&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 21
# City Number: 10953
# City: ondarroa
# Country: es
# http://api.openweathermap.org/data/2.5/weather?q=ondarroa,es&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 22
# City Number: 17816
# City: hailakandi
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=hailakandi,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 23
# City Number: 23852
# City: hopelchen
# Country: mx
# http://api.openweathermap.org/data/2.5/weather?q=hopelchen,mx&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 24
# City Number: 40516
# City: biga
# Country: tr
# http://api.openweathermap.org/data/2.5/weather?q=biga,tr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 25
# City Number: 6298
# City: shangqiu
# Country: cn
# http://api.openweathermap.org/data/2.5/weather?q=shangqiu,cn&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 26
# City Number: 19395
# City: shirhatti
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=shirhatti,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 27
# City Number: 20785
# City: pisa
# Country: it
# http://api.openweathermap.org/data/2.5/weather?q=pisa,it&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 28
# City Number: 36290
# City: khodz
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=khodz,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 29
# City Number: 12201
# City: libreville
# Country: ga
# http://api.openweathermap.org/data/2.5/weather?q=libreville,ga&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 30
# City Number: 20232
# City: carpi
# Country: it
# http://api.openweathermap.org/data/2.5/weather?q=carpi,it&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 31
# City Number: 5085
# City: vulcan
# Country: ca
# http://api.openweathermap.org/data/2.5/weather?q=vulcan,ca&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 32
# City Number: 20219
# City: carate brianza
# Country: it
# http://api.openweathermap.org/data/2.5/weather?q=carate+brianza,it&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 33
# City Number: 6898
# City: gonzalez
# Country: co
# http://api.openweathermap.org/data/2.5/weather?q=gonzalez,co&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 34
# City Number: 44647
# City: west orange
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=west+orange,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 35
# City Number: 20552
# City: lonigo
# Country: it
# http://api.openweathermap.org/data/2.5/weather?q=lonigo,it&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 36
# City Number: 304
# City: marmarashen
# Country: am
# http://api.openweathermap.org/data/2.5/weather?q=marmarashen,am&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 37
# City Number: 17221
# City: bhagalpur
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=bhagalpur,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 38
# City Number: 1060
# City: bosanska krupa
# Country: ba
# http://api.openweathermap.org/data/2.5/weather?q=bosanska+krupa,ba&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 39
# City Number: 39919
# City: delgado
# Country: sv
# http://api.openweathermap.org/data/2.5/weather?q=delgado,sv&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 40
# City Number: 33547
# City: merei
# Country: ro
# http://api.openweathermap.org/data/2.5/weather?q=merei,ro&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 41
# City Number: 13995
# City: nea pella
# Country: gr
# http://api.openweathermap.org/data/2.5/weather?q=nea+pella,gr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 42
# City Number: 36696
# City: kurchatov
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=kurchatov,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 43
# City Number: 43407
# City: woodridge
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=woodridge,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 44
# City Number: 2200
# City: montero
# Country: bo
# http://api.openweathermap.org/data/2.5/weather?q=montero,bo&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 45
# City Number: 27934
# City: concepcion
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=concepcion,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 46
# City Number: 19923
# City: kuhdasht
# Country: ir
# http://api.openweathermap.org/data/2.5/weather?q=kuhdasht,ir&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 47
# City Number: 7417
# City: suaza
# Country: co
# http://api.openweathermap.org/data/2.5/weather?q=suaza,co&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 48
# City Number: 8964
# City: hamminkeln
# Country: de
# http://api.openweathermap.org/data/2.5/weather?q=hamminkeln,de&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 49
# City Number: 15232
# City: valle de angeles
# Country: hn
# http://api.openweathermap.org/data/2.5/weather?q=valle+de+angeles,hn&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 50
# City Number: 42648
# City: craig
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=craig,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 51
# City Number: 1244
# City: voljevac
# Country: ba
# http://api.openweathermap.org/data/2.5/weather?q=voljevac,ba&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 52
# City Number: 4279
# City: nassau
# Country: bs
# http://api.openweathermap.org/data/2.5/weather?q=nassau,bs&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 53
# City Number: 1905
# City: batak
# Country: bg
# http://api.openweathermap.org/data/2.5/weather?q=batak,bg&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 54
# City Number: 23842
# City: hermosillo
# Country: mx
# http://api.openweathermap.org/data/2.5/weather?q=hermosillo,mx&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 55
# City Number: 37880
# City: reutov
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=reutov,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 56
# City Number: 6185
# City: luoyang
# Country: cn
# http://api.openweathermap.org/data/2.5/weather?q=luoyang,cn&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 57
# City Number: 15115
# City: san antonio del norte
# Country: hn
# http://api.openweathermap.org/data/2.5/weather?q=san+antonio+del+norte,hn&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 58
# City Number: 27333
# City: baroy
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=baroy,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 59
# City Number: 38353
# City: staroshcherbinovskaya
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=staroshcherbinovskaya,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 60
# City Number: 12054
# City: sarcelles
# Country: fr
# http://api.openweathermap.org/data/2.5/weather?q=sarcelles,fr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 61
# City Number: 23784
# City: empalme
# Country: mx
# http://api.openweathermap.org/data/2.5/weather?q=empalme,mx&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 62
# City Number: 5676
# City: melipilla
# Country: cl
# http://api.openweathermap.org/data/2.5/weather?q=melipilla,cl&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 63
# City Number: 40314
# City: tha mai
# Country: th
# http://api.openweathermap.org/data/2.5/weather?q=tha+mai,th&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 64
# City Number: 33323
# City: ipotesti
# Country: ro
# http://api.openweathermap.org/data/2.5/weather?q=ipotesti,ro&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 65
# City Number: 31821
# City: sobreda
# Country: pt
# http://api.openweathermap.org/data/2.5/weather?q=sobreda,pt&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 66
# City Number: 29638
# City: ranao
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=ranao,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 67
# City Number: 37655
# City: pirogovskiy
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=pirogovskiy,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 68
# City Number: 39920
# City: el congo
# Country: sv
# http://api.openweathermap.org/data/2.5/weather?q=el+congo,sv&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 69
# City Number: 36880
# City: lvovskiy
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=lvovskiy,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 70
# City Number: 29382
# City: pandan
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=pandan,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 71
# City Number: 40918
# City: kibondo
# Country: tz
# http://api.openweathermap.org/data/2.5/weather?q=kibondo,tz&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 72
# City Number: 27070
# City: aplaya
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=aplaya,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 73
# City Number: 15511
# City: dunafoldvar
# Country: hu
# http://api.openweathermap.org/data/2.5/weather?q=dunafoldvar,hu&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 74
# City Number: 2852
# City: embu
# Country: br
# http://api.openweathermap.org/data/2.5/weather?q=embu,br&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 75
# City Number: 7352
# City: santa isabel
# Country: co
# http://api.openweathermap.org/data/2.5/weather?q=santa+isabel,co&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 76
# City Number: 40154
# City: kalasin
# Country: th
# http://api.openweathermap.org/data/2.5/weather?q=kalasin,th&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 77
# City Number: 31978
# City: pirapo
# Country: py
# http://api.openweathermap.org/data/2.5/weather?q=pirapo,py&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 78
# City Number: 41670
# City: rozhyshche
# Country: ua
# http://api.openweathermap.org/data/2.5/weather?q=rozhyshche,ua&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 79
# City Number: 17015
# City: babugarh
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=babugarh,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 80
# City Number: 26458
# City: la pena
# Country: pa
# http://api.openweathermap.org/data/2.5/weather?q=la+pena,pa&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 81
# City Number: 31379
# City: tomaszow lubelski
# Country: pl
# http://api.openweathermap.org/data/2.5/weather?q=tomaszow+lubelski,pl&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 82
# City Number: 44047
# City: farmington hills
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=farmington+hills,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 83
# City Number: 21960
# City: yukuhashi
# Country: jp
# http://api.openweathermap.org/data/2.5/weather?q=yukuhashi,jp&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 84
# City Number: 13097
# City: kaspi
# Country: ge
# http://api.openweathermap.org/data/2.5/weather?q=kaspi,ge&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 85
# City Number: 32755
# City: cornesti
# Country: ro
# http://api.openweathermap.org/data/2.5/weather?q=cornesti,ro&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 86
# City Number: 20009
# City: zanjan
# Country: ir
# http://api.openweathermap.org/data/2.5/weather?q=zanjan,ir&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 87
# City Number: 4856
# City: peace river
# Country: ca
# http://api.openweathermap.org/data/2.5/weather?q=peace+river,ca&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 88
# City Number: 37615
# City: peski
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=peski,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 89
# City Number: 29205
# City: nalundan
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=nalundan,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 90
# City Number: 8909
# City: goch
# Country: de
# http://api.openweathermap.org/data/2.5/weather?q=goch,de&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 91
# City Number: 3215
# City: joao monlevade
# Country: br
# http://api.openweathermap.org/data/2.5/weather?q=joao+monlevade,br&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 92
# City Number: 42342
# City: hawaiian gardens
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=hawaiian+gardens,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 93
# City Number: 42072
# City: tuscaloosa
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=tuscaloosa,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 94
# City Number: 1224
# City: travnik
# Country: ba
# http://api.openweathermap.org/data/2.5/weather?q=travnik,ba&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 95
# City Number: 11093
# City: valverde del camino
# Country: es
# http://api.openweathermap.org/data/2.5/weather?q=valverde+del+camino,es&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 96
# City Number: 29922
# City: san mariano
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=san+mariano,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 97
# City Number: 9836
# City: werder
# Country: de
# http://api.openweathermap.org/data/2.5/weather?q=werder,de&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 98
# City Number: 43319
# City: midlothian
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=midlothian,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 99
# City Number: 37994
# City: sars
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=sars,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 100
# City Number: 40987
# City: masuguru
# Country: tz
# http://api.openweathermap.org/data/2.5/weather?q=masuguru,tz&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 101
# City Number: 15460
# City: csakvar
# Country: hu
# http://api.openweathermap.org/data/2.5/weather?q=csakvar,hu&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 102
# City Number: 7051
# City: marinilla
# Country: co
# http://api.openweathermap.org/data/2.5/weather?q=marinilla,co&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 103
# City Number: 29411
# City: panlaitan
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=panlaitan,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 104
# City Number: 13779
# City: kokkarion
# Country: gr
# http://api.openweathermap.org/data/2.5/weather?q=kokkarion,gr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 105
# City Number: 2951
# City: guaiuba
# Country: br
# http://api.openweathermap.org/data/2.5/weather?q=guaiuba,br&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 106
# City Number: 3344
# City: marechal deodoro
# Country: br
# http://api.openweathermap.org/data/2.5/weather?q=marechal+deodoro,br&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 107
# City Number: 15573
# City: gegeny
# Country: hu
# http://api.openweathermap.org/data/2.5/weather?q=gegeny,hu&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 108
# City Number: 6585
# City: amalfi
# Country: co
# http://api.openweathermap.org/data/2.5/weather?q=amalfi,co&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 109
# City Number: 36475
# City: korenovsk
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=korenovsk,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 110
# City Number: 12816
# City: northam
# Country: gb
# http://api.openweathermap.org/data/2.5/weather?q=northam,gb&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 111
# City Number: 2186
# City: jorochito
# Country: bo
# http://api.openweathermap.org/data/2.5/weather?q=jorochito,bo&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 112
# City Number: 14067
# City: palaiokomi
# Country: gr
# http://api.openweathermap.org/data/2.5/weather?q=palaiokomi,gr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 113
# City Number: 17979
# City: jamuria
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=jamuria,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 114
# City Number: 21720
# City: rumoi
# Country: jp
# http://api.openweathermap.org/data/2.5/weather?q=rumoi,jp&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 115
# City Number: 11725
# City: le bourget
# Country: fr
# http://api.openweathermap.org/data/2.5/weather?q=le+bourget,fr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 116
# City Number: 41239
# City: chutove
# Country: ua
# http://api.openweathermap.org/data/2.5/weather?q=chutove,ua&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 117
# City Number: 2157
# City: camargo
# Country: bo
# http://api.openweathermap.org/data/2.5/weather?q=camargo,bo&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 118
# City Number: 23375
# City: antiguo morelos
# Country: mx
# http://api.openweathermap.org/data/2.5/weather?q=antiguo+morelos,mx&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 119
# City Number: 8783
# City: ennepetal
# Country: de
# http://api.openweathermap.org/data/2.5/weather?q=ennepetal,de&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 120
# City Number: 41162
# City: berezyne
# Country: ua
# http://api.openweathermap.org/data/2.5/weather?q=berezyne,ua&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 121
# City Number: 20105
# City: augusta
# Country: it
# http://api.openweathermap.org/data/2.5/weather?q=augusta,it&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 122
# City Number: 31559
# City: carvalhosa
# Country: pt
# http://api.openweathermap.org/data/2.5/weather?q=carvalhosa,pt&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 123
# City Number: 45238
# City: sherwood
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=sherwood,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 124
# City Number: 21026
# City: sulmona
# Country: it
# http://api.openweathermap.org/data/2.5/weather?q=sulmona,it&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 125
# City Number: 45942
# City: newport news
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=newport+news,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 126
# City Number: 1195
# City: sanica
# Country: ba
# http://api.openweathermap.org/data/2.5/weather?q=sanica,ba&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 127
# City Number: 31483
# City: amora
# Country: pt
# http://api.openweathermap.org/data/2.5/weather?q=amora,pt&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 128
# City Number: 39037
# City: vytegra
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=vytegra,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 129
# City Number: 42048
# City: madison
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=madison,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 130
# City Number: 24510
# City: santos reyes nopala
# Country: mx
# http://api.openweathermap.org/data/2.5/weather?q=santos+reyes+nopala,mx&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 131
# City Number: 5697
# City: rengo
# Country: cl
# http://api.openweathermap.org/data/2.5/weather?q=rengo,cl&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 132
# City Number: 18106
# City: kandhla
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=kandhla,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 133
# City Number: 13606
# City: ierissos
# Country: gr
# http://api.openweathermap.org/data/2.5/weather?q=ierissos,gr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 134
# City Number: 38863
# City: verkhneyarkeyevo
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=verkhneyarkeyevo,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 135
# City Number: 8552
# City: balingen
# Country: de
# http://api.openweathermap.org/data/2.5/weather?q=balingen,de&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 136
# City Number: 43268
# City: glen carbon
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=glen+carbon,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 137
# City Number: 39610
# City: ziri
# Country: si
# http://api.openweathermap.org/data/2.5/weather?q=ziri,si&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 138
# City Number: 31455
# City: albufeira
# Country: pt
# http://api.openweathermap.org/data/2.5/weather?q=albufeira,pt&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 139
# City Number: 24304
# City: piedras negras
# Country: mx
# http://api.openweathermap.org/data/2.5/weather?q=piedras+negras,mx&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 140
# City Number: 46326
# City: el limon
# Country: ve
# http://api.openweathermap.org/data/2.5/weather?q=el+limon,ve&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 141
# City Number: 2162
# City: challapata
# Country: bo
# http://api.openweathermap.org/data/2.5/weather?q=challapata,bo&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 142
# City Number: 19571
# City: tattayyangarpettai
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=tattayyangarpettai,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 143
# City Number: 18971
# City: pattukkottai
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=pattukkottai,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 144
# City Number: 23391
# City: aquiles serdan
# Country: mx
# http://api.openweathermap.org/data/2.5/weather?q=aquiles+serdan,mx&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 145
# City Number: 44742
# City: fulton
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=fulton,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 146
# City Number: 1078
# City: cim
# Country: ba
# http://api.openweathermap.org/data/2.5/weather?q=cim,ba&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 147
# City Number: 39663
# City: nemsova
# Country: sk
# http://api.openweathermap.org/data/2.5/weather?q=nemsova,sk&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 148
# City Number: 21675
# City: ogaki
# Country: jp
# http://api.openweathermap.org/data/2.5/weather?q=ogaki,jp&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 149
# City Number: 27558
# City: buhatan
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=buhatan,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 150
# City Number: 41791
# City: torez
# Country: ua
# http://api.openweathermap.org/data/2.5/weather?q=torez,ua&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 151
# City Number: 13418
# City: aria
# Country: gr
# http://api.openweathermap.org/data/2.5/weather?q=aria,gr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 152
# City Number: 46547
# City: barkly west
# Country: za
# http://api.openweathermap.org/data/2.5/weather?q=barkly+west,za&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 153
# City Number: 46402
# City: cao bang
# Country: vn
# http://api.openweathermap.org/data/2.5/weather?q=cao+bang,vn&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 154
# City Number: 3488
# City: nova odessa
# Country: br
# http://api.openweathermap.org/data/2.5/weather?q=nova+odessa,br&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 155
# City Number: 7753
# City: sagua la grande
# Country: cu
# http://api.openweathermap.org/data/2.5/weather?q=sagua+la+grande,cu&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 156
# City Number: 28796
# City: mabini
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=mabini,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 157
# City Number: 15283
# City: pula
# Country: hr
# http://api.openweathermap.org/data/2.5/weather?q=pula,hr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 158
# City Number: 17588
# City: dhupgari
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=dhupgari,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 159
# City Number: 44984
# City: bexley
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=bexley,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 160
# City Number: 26884
# City: bulolo
# Country: pg
# http://api.openweathermap.org/data/2.5/weather?q=bulolo,pg&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 161
# City Number: 472
# City: azul
# Country: ar
# http://api.openweathermap.org/data/2.5/weather?q=azul,ar&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 162
# City Number: 11634
# City: gerzat
# Country: fr
# http://api.openweathermap.org/data/2.5/weather?q=gerzat,fr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 163
# City Number: 22857
# City: demir kapija
# Country: mk
# http://api.openweathermap.org/data/2.5/weather?q=demir+kapija,mk&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 164
# City Number: 6891
# City: genova
# Country: co
# http://api.openweathermap.org/data/2.5/weather?q=genova,co&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 165
# City Number: 2658
# City: capim grosso
# Country: br
# http://api.openweathermap.org/data/2.5/weather?q=capim+grosso,br&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 166
# City Number: 41801
# City: tyachiv
# Country: ua
# http://api.openweathermap.org/data/2.5/weather?q=tyachiv,ua&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 167
# City Number: 122
# City: permet
# Country: al
# http://api.openweathermap.org/data/2.5/weather?q=permet,al&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 168
# City Number: 20127
# City: barrafranca
# Country: it
# http://api.openweathermap.org/data/2.5/weather?q=barrafranca,it&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 169
# City Number: 32840
# City: curatele
# Country: ro
# http://api.openweathermap.org/data/2.5/weather?q=curatele,ro&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 170
# City Number: 43752
# City: college park
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=college+park,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 171
# City Number: 11599
# City: figeac
# Country: fr
# http://api.openweathermap.org/data/2.5/weather?q=figeac,fr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 172
# City Number: 10723
# City: boadilla del monte
# Country: es
# http://api.openweathermap.org/data/2.5/weather?q=boadilla+del+monte,es&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 173
# City Number: 33101
# City: garbovi
# Country: ro
# http://api.openweathermap.org/data/2.5/weather?q=garbovi,ro&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 174
# City Number: 39803
# City: bignona
# Country: sn
# http://api.openweathermap.org/data/2.5/weather?q=bignona,sn&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 175
# City Number: 11365
# City: argentan
# Country: fr
# http://api.openweathermap.org/data/2.5/weather?q=argentan,fr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 176
# City Number: 37054
# City: mishkino
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=mishkino,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 177
# City Number: 36675
# City: kuloy
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=kuloy,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 178
# City Number: 46096
# City: de pere
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=de+pere,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 179
# City Number: 8345
# City: uhersky ostroh
# Country: cz
# http://api.openweathermap.org/data/2.5/weather?q=uhersky+ostroh,cz&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 180
# City Number: 5735
# City: bafut
# Country: cm
# http://api.openweathermap.org/data/2.5/weather?q=bafut,cm&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 181
# City Number: 26608
# City: cascas
# Country: pe
# http://api.openweathermap.org/data/2.5/weather?q=cascas,pe&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 182
# City Number: 28063
# City: diffun
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=diffun,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 183
# City Number: 43692
# City: kittery
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=kittery,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 184
# City Number: 28824
# City: madalag
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=madalag,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 185
# City Number: 33518
# City: margineni
# Country: ro
# http://api.openweathermap.org/data/2.5/weather?q=margineni,ro&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 186
# City Number: 588
# City: ebenthal
# Country: at
# http://api.openweathermap.org/data/2.5/weather?q=ebenthal,at&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 187
# City Number: 30405
# City: tamlang
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=tamlang,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 188
# City Number: 4156
# City: tremedal
# Country: br
# http://api.openweathermap.org/data/2.5/weather?q=tremedal,br&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 189
# City Number: 37902
# City: roshchino
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=roshchino,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 190
# City Number: 15022
# City: marale
# Country: hn
# http://api.openweathermap.org/data/2.5/weather?q=marale,hn&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 191
# City Number: 39987
# City: tenancingo
# Country: sv
# http://api.openweathermap.org/data/2.5/weather?q=tenancingo,sv&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 192
# City Number: 3848
# City: santa adelia
# Country: br
# http://api.openweathermap.org/data/2.5/weather?q=santa+adelia,br&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 193
# City Number: 21243
# City: chigasaki
# Country: jp
# http://api.openweathermap.org/data/2.5/weather?q=chigasaki,jp&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 194
# City Number: 45491
# City: socastee
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=socastee,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 195
# City Number: 3082
# City: itacarambi
# Country: br
# http://api.openweathermap.org/data/2.5/weather?q=itacarambi,br&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 196
# City Number: 8717
# City: dinkelsbuhl
# Country: de
# http://api.openweathermap.org/data/2.5/weather?q=dinkelsbuhl,de&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 197
# City Number: 44827
# City: port chester
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=port+chester,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 198
# City Number: 32620
# City: certesti
# Country: ro
# http://api.openweathermap.org/data/2.5/weather?q=certesti,ro&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 199
# City Number: 45700
# City: lake jackson
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=lake+jackson,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 200
# City Number: 9954
# City: egtved
# Country: dk
# http://api.openweathermap.org/data/2.5/weather?q=egtved,dk&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 201
# City Number: 27552
# City: bugko
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=bugko,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 202
# City Number: 8113
# City: milevsko
# Country: cz
# http://api.openweathermap.org/data/2.5/weather?q=milevsko,cz&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 203
# City Number: 11098
# City: vigo
# Country: es
# http://api.openweathermap.org/data/2.5/weather?q=vigo,es&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 204
# City Number: 13572
# City: galatades
# Country: gr
# http://api.openweathermap.org/data/2.5/weather?q=galatades,gr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 205
# City Number: 9861
# City: wilhelmshaven
# Country: de
# http://api.openweathermap.org/data/2.5/weather?q=wilhelmshaven,de&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 206
# City Number: 18964
# City: patnagarh
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=patnagarh,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 207
# City Number: 26813
# City: tarma
# Country: pe
# http://api.openweathermap.org/data/2.5/weather?q=tarma,pe&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 208
# City Number: 16132
# City: vaja
# Country: hu
# http://api.openweathermap.org/data/2.5/weather?q=vaja,hu&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 209
# City Number: 32323
# City: biertan
# Country: ro
# http://api.openweathermap.org/data/2.5/weather?q=biertan,ro&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 210
# City Number: 43905
# City: hull
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=hull,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 211
# City Number: 45163
# City: duncan
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=duncan,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 212
# City Number: 15101
# City: rio bonito
# Country: hn
# http://api.openweathermap.org/data/2.5/weather?q=rio+bonito,hn&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 213
# City Number: 42505
# City: rio linda
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=rio+linda,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 214
# City Number: 14951
# City: la encarnacion
# Country: hn
# http://api.openweathermap.org/data/2.5/weather?q=la+encarnacion,hn&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 215
# City Number: 21814
# City: tagawa
# Country: jp
# http://api.openweathermap.org/data/2.5/weather?q=tagawa,jp&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ...
# ----------------------------
# Retreiving City #: 392
# City Number: 16669
# City: leixlip
# Country: ie
# http://api.openweathermap.org/data/2.5/weather?q=leixlip,ie&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 393
# City Number: 29874
# City: san jose
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=san+jose,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 394
# City Number: 17089
# City: banda
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=banda,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 395
# City Number: 29280
# City: odiong
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=odiong,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 396
# City Number: 13171
# City: bibiani
# Country: gh
# http://api.openweathermap.org/data/2.5/weather?q=bibiani,gh&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 397
# City Number: 8515
# City: bad mergentheim
# Country: de
# http://api.openweathermap.org/data/2.5/weather?q=bad+mergentheim,de&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 398
# City Number: 379
# City: tashir
# Country: am
# http://api.openweathermap.org/data/2.5/weather?q=tashir,am&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 399
# City Number: 37094
# City: motygino
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=motygino,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 400
# City Number: 30697
# City: bhalwal
# Country: pk
# http://api.openweathermap.org/data/2.5/weather?q=bhalwal,pk&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 401
# City Number: 11816
# City: mennecy
# Country: fr
# http://api.openweathermap.org/data/2.5/weather?q=mennecy,fr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 402
# City Number: 44695
# City: arlington
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=arlington,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 403
# City Number: 45010
# City: dayton
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=dayton,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 404
# City Number: 39506
# City: ankaran
# Country: si
# http://api.openweathermap.org/data/2.5/weather?q=ankaran,si&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 405
# City Number: 18584
# City: manvi
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=manvi,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 406
# City Number: 20934
# City: san remo
# Country: it
# http://api.openweathermap.org/data/2.5/weather?q=san+remo,it&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 407
# City Number: 42441
# City: newport beach
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=newport+beach,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 408
# City Number: 38414
# City: suponevo
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=suponevo,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 409
# City Number: 26454
# City: la mesa
# Country: pa
# http://api.openweathermap.org/data/2.5/weather?q=la+mesa,pa&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 410
# City Number: 36424
# City: koltsovo
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=koltsovo,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 411
# City Number: 196
# City: aygek
# Country: am
# http://api.openweathermap.org/data/2.5/weather?q=aygek,am&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 412
# City Number: 37449
# City: oktyabrskiy
# Country: ru
# http://api.openweathermap.org/data/2.5/weather?q=oktyabrskiy,ru&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 413
# City Number: 22490
# City: capellen
# Country: lu
# http://api.openweathermap.org/data/2.5/weather?q=capellen,lu&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 414
# City Number: 18628
# City: minjur
# Country: in
# http://api.openweathermap.org/data/2.5/weather?q=minjur,in&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 415
# City Number: 28332
# City: indulang
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=indulang,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 416
# City Number: 27909
# City: clarin
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=clarin,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 417
# City Number: 39623
# City: cadca
# Country: sk
# http://api.openweathermap.org/data/2.5/weather?q=cadca,sk&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 418
# City Number: 13933
# City: methoni
# Country: gr
# http://api.openweathermap.org/data/2.5/weather?q=methoni,gr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 419
# City Number: 44789
# City: middletown
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=middletown,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 420
# City Number: 23793
# City: espita
# Country: mx
# http://api.openweathermap.org/data/2.5/weather?q=espita,mx&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 421
# City Number: 11550
# City: creutzwald
# Country: fr
# http://api.openweathermap.org/data/2.5/weather?q=creutzwald,fr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 422
# City Number: 32085
# City: alba iulia
# Country: ro
# http://api.openweathermap.org/data/2.5/weather?q=alba+iulia,ro&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 423
# City Number: 28812
# City: macabugos
# Country: ph
# http://api.openweathermap.org/data/2.5/weather?q=macabugos,ph&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 424
# City Number: 20819
# City: prato
# Country: it
# http://api.openweathermap.org/data/2.5/weather?q=prato,it&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 425
# City Number: 4857
# City: peachland
# Country: ca
# http://api.openweathermap.org/data/2.5/weather?q=peachland,ca&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 426
# City Number: 44955
# City: dickinson
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=dickinson,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 427
# City Number: 46418
# City: hoi an
# Country: vn
# http://api.openweathermap.org/data/2.5/weather?q=hoi+an,vn&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 428
# City Number: 14340
# City: vasiliki
# Country: gr
# http://api.openweathermap.org/data/2.5/weather?q=vasiliki,gr&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 429
# City Number: 43769
# City: ferndale
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=ferndale,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 430
# City Number: 44527
# City: fort dix
# Country: us
# http://api.openweathermap.org/data/2.5/weather?q=fort+dix,us&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 431
# City Number: 31849
# City: ventosa
# Country: pt
# http://api.openweathermap.org/data/2.5/weather?q=ventosa,pt&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
# ----------------------------
# Retreiving City #: 432
# City Number: 19927
# City: mahabad
# Country: ir
# http://api.openweathermap.org/data/2.5/weather?q=mahabad,ir&units=IMPERIAL&mode=json&APPID=e5760248211a864fbc4f4418cc6d872d
#      index Country            City   Latitude   Longitude Temperature  \
# 0    45539      us        gallatin  36.388333  -86.446667        35.6
# 1    42605      us         visalia  36.330278 -119.291111          41
# 2     7354      co     santa maria   2.861389  -75.597778       55.82
# 3    34354      ro        stelnica  44.416667   27.883333        37.4
# 4       82      al          cerrik  41.031667   19.975833          32
# 5    35725      ru           domna  51.897122  113.157302         1.4
# 6    16312      id           kamal  -7.167778  112.719167        89.6
# 7    28434      ph         kapatan   5.900556  125.237500       79.04
# 8    12544      gb     fraserburgh  57.683333   -2.016667        48.2
# 9    19034      in      pithapuram  17.116667   82.266667       75.26
# 10   18262      in       khudaganj  28.150000   79.716667       70.76
# 11   19252      in         saidpur  28.616667   77.916667       71.26
# 12   41693      ua       semenivka  49.590311   33.180486       25.27
# 13   26958      ph            akle  15.048200  121.073300       86.88
# 14   26506      pa          pedasi   7.533333  -80.033333       77.33
# 15   10078      dk  neder vindinge  55.032107   11.883556        44.6
# 16   41418      ua        kulevcha  46.030338   29.936137       38.54
# 17   41385      ua           kosiv  48.310708   25.095752          41
# 18   43852      us       billerica  42.558333  -71.269444       32.02
# 19    1842      be        zonhoven  50.983333    5.350000       37.62
# 20   10953      es        ondarroa  43.325088   -2.423304       39.72
# 21   17816      in      hailakandi  24.683333   92.566667       77.51
# 22   23852      mx       hopelchen  19.766667  -89.850000          77
# 23    4537      ca        clermont  47.683333  -70.233333
# 24   40516      tr            biga  40.228056   27.242222       25.13
# 25    6298      cn        shangqiu  34.383333  115.616667       52.27
# 26   19395      in       shirhatti  15.233333   75.583333       78.41
# 27    7256      co          rondon   5.356415  -73.209178
# 28   15239      hn      vivistorio  14.900000  -88.733333
# 29   37223      ru      nikolskoye  55.193889  165.992500
# ..     ...     ...             ...        ...         ...         ...
# 470  20934      it        san remo  43.816667    7.766667       45.05
# 471  42441      us   newport beach  33.618889 -117.928056       63.59
# 472  38414      ru        suponevo  53.204923   34.295966        28.4
# 473  26454      pa         la mesa   8.150000  -81.183333       71.26
# 474  36424      ru        koltsovo  56.774748   60.825227        21.2
# 475    196      am           aygek  40.188611   44.383333          32
# 476  37449      ru     oktyabrskiy  56.509909   57.204514       26.66
# 477  22490      lu        capellen  49.645000    5.990833        30.2
# 478  18628      in          minjur  13.266667   80.266667        82.4
# 479  28332      ph        indulang   8.050000  124.640000        77.6
# 480  27909      ph          clarin   9.961600  124.025200        81.2
# 481  39623      sk           cadca  49.433333   18.783333       35.73
# 482  13933      gr         methoni  36.816667   21.700000        35.6
# 483  39135      ru         yevsino  54.413600   83.322000
# 484  44789      us      middletown  41.445833  -74.423333       30.81
# 485  23793      mx          espita  21.016667  -88.316667       73.64
# 486  11550      fr      creutzwald  49.199657    6.689863       32.34
# 487  32085      ro      alba iulia  46.066667   23.583333        33.8
# 488  28812      ph       macabugos  13.236200  123.305300       82.82
# 489  22483      lu           biwer  49.702778    6.374722
# 490  20819      it           prato  43.883333   11.100000       33.71
# 491   4857      ca       peachland  49.766667 -119.750000        32.9
# 492  44955      us       dickinson  46.879167 -102.789167       43.34
# 493  46418      vn          hoi an  15.879444  108.335000        75.2
# 494  14340      gr        vasiliki  39.638889   21.704722       20.77
# 495  43769      us        ferndale  39.183056  -76.640556        32.2
# 496  44527      us        fort dix  40.029722  -74.618889       36.43
# 497  31849      pt         ventosa  39.126960   -9.084235       37.85
# 498  19927      ir         mahabad  36.749900   45.722900       34.67
# 499  24298      mx          petapa  16.816667  -95.150000
#
#     Humidity Cloudiness Wind Speed
# 0         80          1       2.84
# 1         70          1       2.73
# 2         97         56       1.95
# 3         93          0      17.22
# 4         80          0       3.36
# 5         84         40       2.24
# 6         62         20      11.41
# 7         95         64       2.62
# 8         61         20      23.04
# 9         61         88       3.74
# 10        84         36       4.97
# 11        86          0       4.74
# 12        90         68      10.78
# 13        58         75        4.7
# 14       100         80       5.97
# 15        87         92       20.8
# 16        99         36      15.03
# 17        92         90       8.95
# 18        74          1        5.3
# 19        90         75      13.87
# 20        65          0       4.85
# 21        80          0       3.96
# 22        88         40      11.41
# 23
# 24        88          0       2.73
# 25        48          0       8.99
# 26        82         36       5.41
# 27
# 28
# 29
# ..       ...        ...        ...
# 470       65         20      14.99
# 471       10         20      24.16
# 472       92         75      11.18
# 473       96         80       2.06
# 474       85         90       8.95
# 475       89         75       2.73
# 476       91         88      12.35
# 477       92         90      10.29
# 478       74         40       5.82
# 479       83          0       3.18
# 480       90         80        3.4
# 481      100         90       1.12
# 482       74          0        4.7
# 483
# 484       64         20       9.17
# 485       83          0       2.84
# 486       96         75      13.87
# 487       86         75       2.24
# 488       86         56       2.95
# 489
# 490      100         75       1.12
# 491       86         90       2.24
# 492       87         90      24.43
# 493       88         75       8.21
# 494       72          0       2.62
# 495       50         90       8.05
# 496       74          1       7.31
# 497       86          0       1.12
# 498       87         44       5.19
# 499
#
# [500 rows x 9 columns]

# %%
randomcitiesDF["Latitude"] = pd.to_numeric(randomcitiesDF["Latitude"])
randomcitiesDF["Longitude"] = pd.to_numeric(randomcitiesDF["Longitude"])
randomcitiesDF["Temperature"] = pd.to_numeric(randomcitiesDF["Temperature"])
randomcitiesDF["Humidity"] = pd.to_numeric(randomcitiesDF["Humidity"])
randomcitiesDF["Cloudiness"] = pd.to_numeric(randomcitiesDF["Cloudiness"])
randomcitiesDF["Wind Speed"] = pd.to_numeric(randomcitiesDF["Wind Speed"])

randomcitiesDF.to_csv("FinalWeather.csv", encoding = "utf-8", index=False)

# %%
# temperature (F) vs. Latitude
# plt.scatter(randomcitiesDF["Latitude"], randomcitiesDF["Temperature"], marker = "o")
sns.lmplot(x = 'Latitude', y = 'Temperature', data = randomcitiesDF, fit_reg= False, size = 7.5)
plt.title("Temperature (F) vs. Latitude")
plt.ylabel("Temperature (F)")
plt.grid()
plt.savefig("temp_v_lat.png")


plt.show()

# %%
# humidity (%) vs. Latitude
sns.lmplot(x = 'Latitude', y = 'Humidity', data = randomcitiesDF, fit_reg= False, size = 7.5)
plt.title("Humidity (%) vs. Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("humidity_v_lat.png")

plt.show()

# %%
# cloudiness (%) vs Latitude

sns.lmplot(x = 'Latitude', y = 'Cloudiness', data = randomcitiesDF, fit_reg= False, size = 7.5)
plt.title("Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("cloudiness_v_lat.png")


plt.show()

# %%
# Latitdue vs Longitdue Bubble Plot with Cloudiness
cloudinessPlot = plt.scatter(x = randomcitiesDF["Longitude"], y = randomcitiesDF["Latitude"], s = randomcitiesDF["Cloudiness"]*5, color = "blue", alpha = 0.5, edgecolor = "black", label = "Cloudiness", )
plt.title("Lat vs Long Bubble Plot Cloudiness")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.Figure = [4,4]
plt.grid()
plt.savefig("cloudiness_bubble.png")


plt.show()

# %%
# wind speed (mph) vs Latitude
sns.lmplot(x = 'Latitude', y = 'Wind Speed', data = randomcitiesDF, fit_reg= True, size = 7.5)
plt.title("Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("wind_v_lat.png")


plt.show()

# %% [markdown]
# ### Observable Trends
# * The closer to 0 latitude the higher the temperature. Per the Temp vs Lat graph, we can see a clear trend that anything from -20 to 20 lat is above 60F. What's interesting is that when you hit 40 latitude or greater the temperature dips below to 40 degrees or lower but at -40 latitude it is still in the 60+ range.
#
#
# * Humidity is at it's highest point of 80 - 100% at 0 to 20 latitude and 40 to 60 latitude.
#
#
# * For the cloudiness vs latitude, there are clumps of 0% and 100% but no clear correlation to the latitude. I decided to create a bubble plot for lat vs longitde with the cloudiness being the size. From here there is a clearer correlation of cloudiness size and % with a large cluster of cloudiness from 0 to 50 longitude and 40 to 60 latitude. This trend can also be seen at -50 to -100 longitude.
#
#
# * For Wind Speed, we can see that the higher the Latitude, the wind speed tends to pick up to a greater speed. There is an upward trend for wind speed as the Latitude is greater.
